# %%
# !pip install -q pyrogram tgcrypto yt-dlp nest_asyncio psutil
print("deps installed")

# %%
import shutil
shutil.copy('/kaggle/input/datasets/exon72727/animeverse2/app.py', '/kaggle/working/app.py')

# %%
from IPython.display import FileLink
FileLink(r'/kaggle/input/datasets/exon72727/animeverse2/app.py')

# %%
exec(open('/kaggle/input/datasets/exon72727/animeverse2/app.py', encoding='utf-8').read())
