# %%
# !pip install -q pyrogram tgcrypto yt-dlp nest_asyncio psutil
print("deps installed")
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.7/183.7 kB 607.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 30.7 MB/s eta 0:00:00
# ...
# deps installed

# %%
import shutil
shutil.copy('/kaggle/input/datasets/exon72727/animeverse5/rtvg.py', '/kaggle/working/app.py')
# Out:
# '/kaggle/working/app.py'
